# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushman2005-cmyk/PPML-EXPERIMENTS/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = input("Enter a 5-digit number:")
for i in range(0, len(n), 2):
    print(n[i])
# Out:
# Enter a 5-digit number:12345
# 1
# 3
# 5

# %%
n = input("Enter a number:")
rev = ""
for i in range(len(n)-1, -1, -1):
  rev = rev + n[i]
if rev == n:
  print("Palindrome Number")
else:
  print("Not a palindrome")
# Out:
# Enter a number:123
# Not a palindrome

# %%
n = int(input("Enter a number:"))
sum = 0
for i in range(1, n):
  if n % i == 0:
    sum = sum + i
if sum == n:
  print("Perfect Number")
else:
  print("Not a perfect number")
# Out:
# Enter a number:28
# Perfect Number

# %%
s = input("Enter a string: ")
rev = ""
vowels = 0
consonants = 0
for ch in s:
    rev = ch + rev
    if ch in "aeiouAEIOU":
        vowels += 1
    elif ch != " ":
        consonants += 1
print("Reversed string:", rev)
print("Vowels:", vowels)
print("Consonants:", consonants)
# Out:
# Enter a string: Ayushman
# Reversed string: namhsuyA
# Vowels: 3
# Consonants: 5

# %%
n = float(input("Enter distance in meters: "))
km = n / 1000
print("Distance in kilometers:", km)
# Out:
# Enter distance in meters: 1000
# Distance in kilometers: 1.0

# %%
min = float(input("Enter the minutes: "))

hrs = min // 60
min = min % 60

print("Time is", hrs, ":", min)
# Out:
# Enter the minutes: 60.5
# Time is 1.0 : 0.5
